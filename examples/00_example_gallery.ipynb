# %% [markdown]
# # 00: Example Gallery & Tutorial Suite Index
#
# ### Repository Architecture & Core Module Mapping
# ```
#                                   [ Core Python Modules ]
#                                             │
#     ┌───────────────────┬───────────────────┼───────────────────┬───────────────────┐
#     ▼                   ▼                   ▼                   ▼                   ▼
# core.synthetic_gen   core.signal_processing  core.spectral_anal   core.parsers      core.config
#     │                   │                   │                   │                   │
#     ▼                   ▼                   ▼                   ▼                   ▼
# [01_signal_gen]      [02_preproc]        [04_multitaper_psd]  [08_uran4_obs]      [Global Config]
#                      [03_wavelet]        [05_cross_spec]
#                                          [06_validation]
#                                          [07_complete_pipe]
# ```
#
# ### Tutorial Index & Execution Matrix
#
# | Notebook | Title | Key Concepts & Physical Focus | Est. Time |
# | :--- | :--- | :--- | :--- |
# | **[00_example_gallery.ipynb](00_example_gallery.ipynb)** | Gallery & Index | Master index, architecture map, dependency verification. | 2 min |
# | **[01_signal_generation.ipynb](01_signal_generation.ipynb)** | Signal Generation | Kolmogorov turbulence ($f^{-8/3}$), harmonic modes, time delay injection. | 5 min |
# | **[02_preprocessing.ipynb](02_preprocessing.ipynb)** | Signal Preprocessing | Hampel spike rejection, Red Noise gap synthesis, Savitzky-Golay, Butterworth scale separation. | 8 min |
# | **[03_wavelet_analysis.ipynb](03_wavelet_analysis.ipynb)** | Wavelet Analysis | STFT vs. Morse CWT vs. Morse SST, non-stationary chirps, SST ridge tracking. | 10 min |
# | **[04_multitaper_psd.ipynb](04_multitaper_psd.ipynb)** | Multitaper PSD | FFT vs. Welch vs. Thomson MTM PSD, Jackknife 95% CIs, Thomson F-test line detection. | 8 min |
# | **[05_cross_spectrum_velocity.ipynb](05_cross_spectrum_velocity.ipynb)** | Cross-Spectral Velocity | Dual-channel CPSD, coherence $\gamma^2(f)$, phase unwrapping, drift velocity $v$. | 10 min |
# | **[06_validation_pipeline.ipynb](06_validation_pipeline.ipynb)** | Baseline Pipeline Validation | Quantitative parameter recovery metrics ($\tau, v, T_1$), noise sensitivity sweep. | 10 min |
# | **[07_complete_pipeline_validation.ipynb](07_complete_pipeline_validation.ipynb)** | Capstone Pipeline Benchmark | 9-stage pipeline, failure mode demos, PCHIP upsampling, Morse SST scalograms, runtime dashboard. | 15 min |
# | **[08_real_uran4_observation.ipynb](08_real_uran4_observation.ipynb)** | Real URAN-4 Observation | Observational paper narrative, 20/25 MHz data (`23022013.PM6`), DQA, physical uncertainty, provenance. | 15 min |
#
# ### Recommended Learning Paths
# 1. **Observational Radio Astronomy**: Execute `00` $\rightarrow$ `05` $\rightarrow$ `08`
# 2. **DSP & Signal Processing**: Execute `01` $\rightarrow$ `02` $\rightarrow$ `03` $\rightarrow$ `04` $\rightarrow$ `07`
# 3. **Complete Suite Walkthrough**: Execute sequentially `00` through `08`

# %%
# Environment Dependency Verification
import sys

import matplotlib
import numpy as np
import pandas as pd
import scipy
import ssqueezepy

print("=== Environment Dependency Verification ===")
print(f"  Python Version:     {sys.version.split()[0]}")
print(f"  NumPy Version:      {np.__version__}")
print(f"  SciPy Version:      {scipy.__version__}")
print(f"  Pandas Version:     {pd.__version__}")
print(f"  Matplotlib Version: {matplotlib.__version__}")
print(f"  SSQueezePy Version: {ssqueezepy.__version__}")
print("\nAll dependencies verified successfully.")
# Out:
# === Environment Dependency Verification ===
#   Python Version:     3.11.8
#   NumPy Version:      2.4.6
#   SciPy Version:      1.17.1
#   Pandas Version:     3.0.3
#   Matplotlib Version: 3.11.0
#   SSQueezePy Version: 0.6.6
#
# All dependencies verified successfully.
